# %% [markdown]
# # Lazy Predict
#
# LazyClassifier is fit on the data to get an idea of which models are most worth investigating.
#
# Before fitting, the target variable is changed to numerical type and the categorical features are one hot encoded.
#
# The models to investigate further are:
# - Nearest Centroid
# - XGBoost
# - Bagging Classifier
# - Logistic Regression

# %%
# change directory to the repository
import os
os.chdir(r"C:\Users\mattc\OneDrive\Documents\Data\Apziva\uyBvjh22fVpcb3UX")
os.getcwd()
# Out:
# 'C:\\Users\\mattc\\OneDrive\\Documents\\Data\\Apziva\\uyBvjh22fVpcb3UX'

# %%
# import all the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display, Markdown
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# set random state for the notebook
random_state = 42
np.random.seed(random_state)

# %%
# import the data
data = pd.read_csv("data/raw/term-deposit-marketing.csv")

# %%
# changing the target column from object to numerical (binary) type
data['target'] = data['y'].map({'no': 0, 'yes': 1})
data = data.drop(columns=['y'])

# %%
# split data into x and y
x = data.drop(columns=['target'])
y = data['target']

# %%
# split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state, stratify=y)

# %%
# one hot encoding categorical columns
cat_features = x.select_dtypes(include='object').columns

encoder = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
], remainder='passthrough')

x_train_processed = encoder.fit_transform(x_train).toarray()
x_test_processed = encoder.transform(x_test).toarray()

# %%
# fitting lazy classifier to encoded data and viewing model performances
lzclf = LazyClassifier(verbose=1, ignore_warnings=True)
models, predictions = lzclf.fit(x_train_processed, x_test_processed, y_train, y_test)
models
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# NearestCentroid                0.878250           0.827687  0.922029
# LinearDiscriminantAnalysis     0.935875           0.704288  0.927262
# XGBClassifier                  0.936125           0.702831  0.946096
# DecisionTreeClassifier         0.919500           0.694666  0.694666
# BaggingClassifier              0.936750           0.677690  0.907360
# ExtraTreeClassifier            0.913000           0.668073  0.668073
# LogisticRegression             0.938375           0.649107  0.931028
# CalibratedClassifierCV         0.937875           0.648041  0.931767
# RandomForestClassifier         0.935625           0.640459  0.937653
# PassiveAggressiveClassifier    0.902875           0.637934  0.776202
# AdaBoostClassifier             0.933250           0.635994  0.917862
# Perceptron                     0.898250           0.635441  0.698123
# SVC                            0.935625           0.614981  0.921639
# LinearSVC                      0.934750           0.604159  0.931751
# ExtraTreesClassifier           0.931625           0.599290  0.924887
# KNeighborsClassifier           0.929625           0.595027  0.796531
# SGDClassifier                  0.934000           0.590220  0.887108
# GaussianNB                     0.240125           0.580069  0.841927
# BernoulliNB                    0.921000           0.576843  0.844484
# RidgeClassifier                0.932375           0.574217  0.927262
# RidgeClassifierCV              0.932375           0.574217  0.927264
# QuadraticDiscriminantAnalysis  0.131500           0.517538  0.719957
# DummyClassifier                0.927625           0.500000  0.500000
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# NearestCentroid                0.898266   0.934178  0.878250    0.187641
# LinearDiscriminantAnalysis     0.931664   0.929066  0.935875    0.245368
# XGBClassifier                  0.931726   0.929097  0.936125    0.454502
# DecisionTreeClassifier         0.919045   0.918602  0.919500    0.508299
# BaggingClassifier              0.929873   0.927172  0.936750    2.635565
# ExtraTreeClassifier            0.912294   0.911609  0.913000    0.234841
# LogisticRegression             0.927978   0.927265  0.938375    0.165409
# CalibratedClassifierCV         0.927488   0.926525  0.937875    1.423122
# RandomForestClassifier         0.924960   0.923131  0.935625    4.176797
# PassiveAggressiveClassifier    0.902836   0.902798  0.902875    0.216713
# AdaBoostClassifier             0.922739   0.919884  0.933250    2.815822
# Perceptron                     0.899660   0.901123  0.898250    0.206417
# SVC                            0.921582   0.922213  0.935625   20.719625
# LinearSVC                      0.919387   0.920551  0.934750    0.389372
# ExtraTreesClassifier           0.916588   0.914842  0.931625    5.085415
# KNeighborsClassifier           0.914646   0.911478  0.929625    1.456954
# SGDClassifier                  0.916666   0.919204  0.934000    0.522342
# GaussianNB                     0.297385   0.924987  0.240125    0.217787
# BernoulliNB                    0.906499   0.899041  0.921000    0.226237
# RidgeClassifier                0.912848   0.915771  0.932375    0.170886
# RidgeClassifierCV              0.912848   0.915771  0.932375    0.263192
# QuadraticDiscriminantAnalysis  0.124934   0.900241  0.131500    0.193785
# DummyClassifier                0.892796   0.860488  0.927625    0.124233
